# %% [markdown]
# # Colab GPU check
#
# Quick smoke test to confirm the free Colab GPU is attached and torch can see it.
#
# Set Runtime > Change runtime type > T4 GPU, then Run all.
#
# Note: torch is already installed on the Colab GPU runtime, so it is not listed in requirements.txt. The Mac side of this project does not need torch.

# %%
# !nvidia-smi

# %%
import torch

print("cuda available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("device:", torch.cuda.get_device_name(0))
    print("gpu is ready")
else:
    print("no gpu - set runtime type to T4 GPU and run again")
